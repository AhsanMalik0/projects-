# %% [markdown]
# <a href="https://colab.research.google.com/github/AhsanMalik0/Practice-Portfolio/blob/main/Yolo_pre_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fareselmenshawii/large-license-plate-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.35G/2.35G [01:46<00:00, 23.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1

# %%
from ultralytics import YOLO
model = YOLO("/content/yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 302MB/s]

# %%
import os
os.listdir(path)
# Out:
# ['labels', 'images']

# %%
os.listdir(os.path.join(path,"images"))
# Out:
# ['val', 'test', 'train']

# %%
train = os.path.join(path,"images/train")
val = os.path.join(path,"images/val")

# %%
train
# Out:
# '/root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/train'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#!pip install onnx
#!pip install tflite_support
#!pip install --force-reinstall tensorflow_decision_forests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 99.8 MB/s eta 0:00:00
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip install onnx2tf
# !pip install onnx_graphsurgeon
# !pip install sng4onnx
# !pip install ai-edge-litert
# !pip install tensorflowjs
# Out:
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.19.0 which is incompatible.
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"

# %%
# !ls
# Out:
# data.yaml  sample_data	yolo11n.pt

# %%
yaml_content = f"""
train: {train}
val: {val}
# Class names
names:
  0: Plate
"""

# Save the YAML file
with open('/content/data.yaml', 'w') as f:
    f.write(yaml_content.strip())  # strip() removes extra whitespace

# %%
results = model.train(
    data='/content/data.yaml',
    epochs=60,
    imgsz=320,
    batch=64,
    device=0,
    name='Licance'
)
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import tarfile

# %%
file_path= "/content/keypoint.zip"

# %%
import zipfile
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall('set')

# %%
with tarfile.open(file_path, 'r:xz') as tar:
    tar.extractall()
    print("Extraction completed.")
# Out:
# Extraction completed.

# %%
# !rm -rf {"/content/set"}

# %%
model = YOLO("/content/set/keypoint/best.pt")

# %%
#model.export(format="tflite")
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/extracted_folder/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 337.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 244.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 321.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 291.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 344.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 249.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 358.0 MB/s eta 0:00:00
# ...

# %%
results = model.train(data="/content/dataset.yaml", epochs=200, imgsz=320,batch=32)
# Out:
# Ultralytics 8.3.113 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Install the ultralytics package from GitHub
# !pip install git+https://github.com/ultralytics/ultralytics.git@main

# %%
model.export(format="tfjs")
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n-pose summary (fused): 109 layers, 2,910,154 parameters, 0 gradients, 7.6 GFLOPs
#
# PyTorch: starting from '/content/set/keypoint/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 62, 8400) (5.9 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 2.4s, saved as '/content/set/keypoint/best.onnx' (11.4 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.27.2...
# TensorFlow SavedModel: export success ✅ 50.9s, saved as '/content/set/keypoint/best_saved_model' (29.6 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.19.0...
# TensorFlow GraphDef: export success ✅ 1.7s, saved as '/content/set/keypoint/best.pb' (11.5 MB)
#
# TensorFlow.js: starting export with tensorflowjs 4.22.0...
#
# ...

# %%
# !pip install tensorflowjs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 104.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 107.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 110.8 MB/s eta 0:00:00
# ...

# %%
model.export(format="tflite")
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n-pose summary (fused): 109 layers, 2,910,154 parameters, 0 gradients, 7.6 GFLOPs
#
# PyTorch: starting from '/content/set/keypoint/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 62, 8400) (5.9 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 2.4s, saved as '/content/set/keypoint/best.onnx' (11.6 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.27.2...
# TensorFlow SavedModel: export success ✅ 47.2s, saved as '/content/set/keypoint/best_saved_model' (30.3 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/set/keypoint/best_saved_model/best_float32.tflite' (11.6 MB)
#
# Export complete (47.8s)
# Results saved to /content/set/keypoint
# ...

# %%
import shutil

folder_path = '/content/runs'
zip_name = '/content/LicancePlate.zip'

shutil.make_archive(zip_name.replace('.zip', ''), 'zip', folder_path)

print(f"Folder zipped to {zip_name}")
# Out:
# Folder zipped to /content/LicancePlate.zip

# %%
ls
# Out:
# calibration_image_sample_data_20x128x128x3_float32.npy  Dataset.tar.xz  runs/         web_yolo.zip
# Dataset/                                                dataset.yaml    sample_data/  yolo11n.pt

# %%
#!pip install mlcroissant
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 31.0 MB/s eta 0:00:00
# ...
#   Created wheel for jsonpath-rw: filename=jsonpath_rw-1.4.0-py3-none-any.whl size=15130 sha256=9968e2ad81c9d1e6bcbcfac11fe7564b9c953315fdc7b0a725614f6a29bbb1a6
#   Stored in directory: /root/.cache/pip/wheels/53/cf/51/a4ea10224b7fdb523e18e2033cadf2a8657517d1f95f3f5413
# Successfully built jsonpath-rw
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("robikscube/textocr-text-extraction-from-images-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.73G/6.73G [01:14<00:00, 97.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/robikscube/textocr-text-extraction-from-images-dataset/versions/2

# %%
# ls /root/.cache/kagglehub/datasets/robikscube/textocr-text-extraction-from-images-dataset/versions/2
# Out:
# annot.csv  annot.parquet  img.csv  img.parquet  TextOCR_0.1_train.json  train_val_images/

# %%
import cv2
import matplotlib.pyplot as  plt

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv('/root/.cache/kagglehub/datasets/robikscube/textocr-text-extraction-from-images-dataset/versions/2/annot.csv')
display(df.head(20))
# Out:
#     Unnamed: 0                   id          image_id  \
# 0            0   a4ea732cd3d5948a_1  a4ea732cd3d5948a
# 1            1   a4ea732cd3d5948a_2  a4ea732cd3d5948a
# 2            2   a4ea732cd3d5948a_3  a4ea732cd3d5948a
# 3            3   a4ea732cd3d5948a_4  a4ea732cd3d5948a
# 4            4   a4ea732cd3d5948a_5  a4ea732cd3d5948a
# 5            5   a4ea732cd3d5948a_6  a4ea732cd3d5948a
# 6            6   a4ea732cd3d5948a_7  a4ea732cd3d5948a
# 7            7   a4ea732cd3d5948a_8  a4ea732cd3d5948a
# 8            8   a4ea732cd3d5948a_9  a4ea732cd3d5948a
# 9            9  a4ea732cd3d5948a_10  a4ea732cd3d5948a
# 10          10  a4ea732cd3d5948a_11  a4ea732cd3d5948a
# 11          11  a4ea732cd3d5948a_12  a4ea732cd3d5948a
# 12          12  a4ea732cd3d5948a_13  a4ea732cd3d5948a
# 13          13  a4ea732cd3d5948a_14  a4ea732cd3d5948a
# 14          14  a4ea732cd3d5948a_15  a4ea732cd3d5948a
# 15          15  a4ea732cd3d5948a_16  a4ea732cd3d5948a
# ...

# %%
import os
from tensorflow import keras
#os.mkdir("/content/jsmodel")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2cd6c9ccbe2e> in <cell line: 0>()
#       1 import os
# ----> 2 from tensorflow import keras
#       3 #os.mkdir("/content/jsmodel")
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import tensorflowjs as tfjs

tfjs.converters.convert_tf_saved_model(
    '/content/extracted_folder/Classification tf model',
    'tfjs_classification',
    #skip_op_check=True,
    metadata={'version': '1.0.0'}  # Optional custom metadata
)
# Out:
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
# ...

# %%
model = keras.models.load_model("/content/FinalRefinement.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
json = model.to_json()

# %%
model.save("/content/Finalrefinement.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('/content/extracted_folder/Classification tf model')
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
